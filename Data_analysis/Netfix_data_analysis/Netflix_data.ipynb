# %%
import pandas as pd
df=pd.read_csv("Netflix Dataset.csv")
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#finding duplicate
df1=df[df.duplicated(keep=False)]
df1
# Out:
#      Show_Id Category              Title        Director  \
# 683     s684    Movie           Backfire     Dave Patten
# 4839   s6621    Movie  The Lost Okoroshi  Abba T. Makama
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 683   Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 4839  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 683       April 5, 2019  TV-MA   97 min
# 4839  September 4, 2020  TV-MA   94 min
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 683   Dramas, Independent Movies, Thrillers
# ...

# %%
#remove duplicate
df.drop_duplicates(keep=False,inplace=True)
df.shape
# Out:
# (7785, 11)

# %%
#with title show the show_id show the director  
df1=df[df["Title"]=="House of Cards"]
df1[['Show_Id','Director']]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#converting the datetime using to_datetie function
df["Date"]=pd.to_datetime(df["Release_Date"])
df.drop("Release_Date",axis=1,inplace=True)

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country Rating  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  TV-MA
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States  PG-13
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
# ...

# %%
#in which year the highest no of tv shows and movie 
df["Date"].dt.year.value_counts()
# Out:
# 2019.0    2152
# 2020.0    2008
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date, dtype: int64

# %%
#bar chart
df["Date"].dt.year.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country Rating  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  TV-MA
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States  PG-13
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
# ...

# %%
#how many movie and tv shows in dataset
df.groupby("Category").Category.count()
# Out:
# Category
# Movie      5375
# TV Show    2410
# Name: Category, dtype: int64

# %%
#bar graph
df.groupby("Category").Category.count().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country Rating  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  TV-MA
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States  PG-13
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
# ...

# %%
#show all the movie in the year 2000 
df["year"]=df["Date"].dt.year
df[(df["year"]==2019)&(df["Category"]=="Movie")].head()
# Out:
#    Show_Id Category   Title             Director  \
# 7       s8    Movie     187       Kevin Reynolds
# 8       s9    Movie     706        Shravan Kumar
# 13     s14    Movie   2,215  Nottapon Boonprakob
# 15     s16    Movie  Oct-01       Kunle Afolayan
# 18     s19    Movie  15-Aug   Swapnaneel Jayakar
#
#                                                  Cast        Country Rating  \
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States      R
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India  TV-14
# 13                                 Artiwara Kongmalai       Thailand  TV-MA
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...        Nigeria  TV-14
# 18  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...          India  TV-14
#
#    Duration                                               Type  \
# 7   119 min                                             Dramas
# 8   118 min                Horror Movies, International Movies
# ...

# %%
#show the title in all tv show that are in india
df[(df["Country"]=="India")&(df["Category"]=="TV Show")]["Title"].head(2)
# Out:
# 86     21 Sarfarosh: Saragarhi 1897
# 132                       7 (Seven)
# Name: Title, dtype: object

# %%
#show top 10 director who gave highest no of tv show and movie
df["Director"].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Kunle Afolayan             8
# Name: Director, dtype: int64

# %%
df["Type"].nunique()
# Out:
# 492

# %%
#show the record
df[(df["Category"]=="Movie")&(df["Type"]=="Comedies")|(df["Country"]=="United States")].head(1)
# Out:
#   Show_Id Category Title     Director  \
# 3      s4    Movie     9  Shane Acker
#
#                                                 Cast        Country Rating  \
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
#
#   Duration                                               Type  \
# 3   80 min  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description       Date    year
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017.0

# %%
#how any movies is tom cruse is cast
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country Rating  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  TV-MA
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States  PG-13
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
# ...

# %%
df[df["Cast"]=="Nasty C"]
# Out:
#      Show_Id Category              Title Director     Cast Country Rating  \
# 7786   s7785    Movie  Zulu Man in Japan      NaN  Nasty C     NaN  TV-MA
#
#      Duration                                               Type  \
# 7786   44 min  Documentaries, International Movies, Music & M...
#
#                                             Description       Date    year
# 7786  In this documentary, South African rapper Nast... 2020-09-25  2020.0

# %%
df["Cast"].value_counts().head(2)
# Out:
# David Attenborough    18
# Samuel West           10
# Name: Cast, dtype: int64

# %%
#str.contains
#if we use str.contains in a particular col that coluun should not have the nul vale
df.dropna(axis=0,inplace=True)
df.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Rating Duration  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  TV-MA   93 min
#
#                            Type  \
# 1  Dramas, International Movies
#
#                                          Description       Date    year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
#different rating
df.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#how any movies got tv14,in canada
df[(df["Category"]=="Movie")&(df["Rating"]=="TV-14")&(df["Country"]=="Canada")].shape
# Out:
# (9, 12)

# %%
#getting r rating after 2018
df[(df["Category"]=="TV Show")&(df["year"]>2018)&(df["Rating"]=="R")]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Rating, Duration, Type, Description, Date, year]
# Index: []

# %%
df.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country Rating  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
#
#   Duration                                               Type  \
# 1   93 min                       Dramas, International Movies
# 2   78 min                Horror Movies, International Movies
# 3   80 min  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description       Date    year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0
# ...

# %%
df.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country Rating  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States  PG-13
#
#   Duration                                               Type  \
# 1   93 min                       Dramas, International Movies
# 2   78 min                Horror Movies, International Movies
# 3   80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4  123 min                                             Dramas
#
# ...

# %%
#minimum duration
#use str.split
df[["Min",'unit']]=df["Duration"].str.split(" ",expand=True)

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Rating  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore      R
#
#   Duration                                 Type  \
# 1   93 min         Dramas, International Movies
# 2   78 min  Horror Movies, International Movies
#
#                                          Description       Date    year Min  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0  93
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0  78
#
#   unit
# 1  min
# 2  min

# %%
df.tail()
# Out:
#      Show_Id Category       Title         Director  \
# 7780   s7779    Movie  Zombieland  Ruben Fleischer
# 7782   s7781    Movie         Zoo     Shlok Sharma
# 7783   s7782    Movie        Zoom     Peter Hewitt
# 7784   s7783    Movie        Zozo      Josef Fares
# 7785   s7784    Movie      Zubaan      Mozez Singh
#
#                                                    Cast  \
# 7780  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 7782  Shashank Arora, Shweta Tripathi, Rahul Kumar, ...
# 7783  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 Country Rating Duration  \
# 7780                                      United States      R   88 min
# 7782                                              India  TV-MA   94 min
# 7783                                      United States     PG   88 min
# ...

# %%
#unit has season to drop
df.set_index("unit")
# Out:
#        Show_Id Category       Title           Director  \
# unit
# min         s2    Movie       07:19  Jorge Michel Grau
# min         s3    Movie       23:59       Gilbert Chan
# min         s4    Movie           9        Shane Acker
# min         s5    Movie          21     Robert Luketic
# Season      s6  TV Show          46        Serdar Akar
# ...        ...      ...         ...                ...
# min      s7779    Movie  Zombieland    Ruben Fleischer
# min      s7781    Movie         Zoo       Shlok Sharma
# min      s7782    Movie        Zoom       Peter Hewitt
# min      s7783    Movie        Zozo        Josef Fares
# min      s7784    Movie      Zubaan        Mozez Singh
#
#                                                      Cast  \
# unit
# min     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# min     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# min     Elijah Wood, John C. Reilly, Jennifer Connelly...
# ...

# %%
df["Min"].max()
# Out:
# '99'

# %%
#highest no of tv show in country
df[df["Category"]=="TV Show"]["Country"].value_counts().head()
# Out:
# United States     27
# United Kingdom    19
# Japan             10
# South Korea       10
# Spain              7
# Name: Country, dtype: int64

# %%
#sort the dateset by year
df.sort_values(by=["year"],ascending=False).head(2)
# Out:
#      Show_Id Category                        Title         Director  \
# 3034   s3035    Movie                Into the Wild        Sean Penn
# 7572   s7571    Movie  What's Eating Gilbert Grape  Lasse Hallström
#
#                                                    Cast        Country Rating  \
# 3034  Emile Hirsch, Marcia Gay Harden, William Hurt,...  United States      R
# 7572  Johnny Depp, Leonardo DiCaprio, Juliette Lewis...  United States  PG-13
#
#      Duration                                            Type  \
# 3034  148 min  Action & Adventure, Dramas, Independent Movies
# 7572  118 min      Classic Movies, Dramas, Independent Movies
#
#                                             Description       Date    year  \
# 3034  A young man gives up everything – including hi... 2021-01-01  2021.0
# 7572  In a backwater Iowa town, young Gilbert is tor... 2021-01-01  2021.0
#
#       Min unit
# 3034  148  min
# 7572  118  min

# %%
df[(df["Type"]=="Dramas")&(df["Category"]=="Movie")].shape
# Out:
# (114, 14)

# %%
#solution
df[(df["Category"]=="TV Show")&(df["Type"]=="Kids' TV")].shape
# Out:
# (4, 14)

# %%
df[(df["Category"]=="TV Show")&(df["Type"]=="Kids' TV")|(df["Type"]=="Dramas")&(df["Category"]=="Movie")]
# Out:
#      Show_Id Category                       Title          Director  \
# 4         s5    Movie                          21    Robert Luketic
# 7         s8    Movie                         187    Kevin Reynolds
# 170     s171    Movie                A Family Man     Mark Williams
# 232     s233    Movie  A Stoning in Fulham County     Larry Elikann
# 276     s277  TV Show                Abby Hatcher       Kyran Kelly
# ...      ...      ...                         ...               ...
# 7422   s7421    Movie                     Villain  Philip Barantini
# 7449   s7448    Movie                         VS.          Ed Lilly
# 7465   s7464    Movie                   Wakefield     Robin Swicord
# 7480   s7479    Movie                   War Horse  Steven Spielberg
# 7668   s7667  TV Show               World of Winx    Iginio Straffi
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
#converting to dict
df_dict=df.to_dict("records")
#initalizing mongodb
from pymongo import MongoClient
Nithish=MongoClient("mongodb://nithish_24:Nithsh24ac-d1lm2ra-shard-00-00.uvpkmyg.mongodb.net:27017,ac-d1lm2ra-shard-00-01.uvpkmyg.mongodb.net:27017,ac-d1lm2ra-shard-00-02.uvpkmyg.mongodb.net:27017/?ssl=true&replicaSet=atlas-aohy3c-shard-0&authSource=admin&retryWrites=true&w=majority")
db=Nithish["Netflix_data"]#creating database
c=db["Movies_tvshow"]#creating colletion
c.insert_many(df_dict)#uploading the docment as dict to server
